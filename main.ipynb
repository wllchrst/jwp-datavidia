# %%
import pandas as pd
import warnings
import numpy as np
from datasets import Dataset
from sklearn.model_selection import train_test_split
from transformers import AutoModelForCausalLM, T5Tokenizer, TrainingArguments, Trainer

warnings.filterwarnings('ignore')

# %%
MODEL_NAME = "amazon/chronos-t5-mini"
features = ["timestamp", "GlobalOpen", "GlobalHigh", "GlobalLow", "GlobalVol.", 
            "GlobalChange %", "GlobalPrice", "CE_Close", "CE_High", "CE_Low", "CE_Open"]
target = "price"

# %%
def date_to_timestamp(df: pd.DataFrame, column='Date') -> pd.DataFrame:
    df['timestamp'] = pd.to_datetime(df[column]).astype(np.int64)
    df.drop(columns=[column], inplace=True)
    return df

# %%
df_train_dataset = pd.read_csv('./AdditionalDataset/training_dataset.csv')
df_test_dataset = pd.read_csv('./AdditionalDataset/testing_dataset.csv')

df_train_dataset.drop(columns=['Unnamed: 0'], inplace=True)
df_test_dataset.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_train_dataset = date_to_timestamp(df_train_dataset)
df_test_dataset = date_to_timestamp(df_test_dataset)

# %%
df_train_dataset = df_train_dataset[features + [target]]
df_train_dataset.head()
# Out:
#              timestamp  GlobalOpen  GlobalHigh  GlobalLow  GlobalVol.  \
# 0  1640995200000000000    205.9048      782.25        3.5    228640.0
# 1  1640995200000000000    205.9048      782.25        3.5    228640.0
# 2  1640995200000000000    205.9048      782.25        3.5    228640.0
# 3  1640995200000000000    205.9048      782.25        3.5    228640.0
# 4  1640995200000000000    205.9048      782.25        3.5    228640.0
#
#    GlobalChange %  GlobalPrice     CE_Close       CE_High    CE_Low  \
# 0           -0.48     202.7536  3554.002863  14301.299805  0.029976
# 1           -0.48     202.7536  3554.002863  14301.299805  0.029976
# 2           -0.48     202.7536  3554.002863  14301.299805  0.029976
# 3           -0.48     202.7536  3554.002863  14301.299805  0.029976
# 4           -0.48     202.7536  3554.002863  14301.299805  0.029976
#
#        CE_Open    price
# 0  3561.752985  28970.0
# 1  3561.752985  27440.0
# 2  3561.752985  11030.0
# 3  3561.752985  12080.0
# 4  3561.752985  22360.0

# %%
df_train_dataset, df_val_dataset = train_test_split(df_train_dataset, test_size=0.2)

# %%
df_train_dataset.head()
# Out:
#                   timestamp  GlobalOpen  GlobalHigh  GlobalLow  GlobalVol.  \
# 352709  1674691200000000000   239.67860      758.00      2.680    471080.0
# 316871  1658880000000000000   264.24420      818.75      8.345    313000.0
# 159103  1653782400000000000   136.55175      406.65      8.275    137720.0
# 312476  1708819200000000000   160.39540      592.50      1.683    353230.0
# 324027  1710979200000000000   156.09580      552.50      1.797    348130.0
#
#         GlobalChange %  GlobalPrice     CE_Close       CE_High    CE_Low  \
# 352709        0.361667     242.2616  3734.931638  14981.599609  0.030441
# 316871       -0.071667     262.2288  3745.942885  15026.299805  0.027115
# 159103       -0.265000     136.8005  3646.296387  14626.000000  0.029220
# 312476       -2.001667     158.6598  3897.245561  15631.000000  0.027685
# 324027       -0.185000     156.2062  3921.996428  15724.599609  0.027525
#
#             CE_Open    price
# 352709  3734.931638  30940.0
# 316871  3745.942885  10610.0
# 159103  3646.296387  28870.0
# 312476  3897.245561  15370.0
# 324027  3921.996428  47010.0

# %%
train_dataset = Dataset.from_pandas(df_train_dataset)
val_dataset = Dataset.from_pandas(df_val_dataset)
test_dataset = Dataset.from_pandas(df_test_dataset)

# %%
tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)

def tokenize_function(example):
    input_features = [example[f] for f in features]
    return tokenizer(" ".join(map(str, input_features)), return_tensors="pt")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)
#       3 def tokenize_function(example):
#       4     input_features = [example[f] for f in features]
#
# File c:\Users\LM23-2\AppData\Local\anaconda3\envs\Python312\Lib\site-packages\transformers\utils\import_utils.py:1736, in DummyObject.__getattribute__(cls, key)
#    1734 if key.startswith("_") and key != "_from_config":
#    1735     return super().__getattribute__(key)
# -> 1736 requires_backends(cls, cls._backends)
#
# File c:\Users\LM23-2\AppData\Local\anaconda3\envs\Python312\Lib\site-packages\transformers\utils\import_utils.py:1724, in requires_backends(obj, backends)
#    1722 failed = [msg.format(name) for available, msg in checks if not available()]
#    1723 if failed:
# -> 1724     raise ImportError("".join(failed))
#
# ImportError:
# T5Tokenizer requires the SentencePiece library but it was not found in your environment. Checkout the instructions on the
# installation page of its repo: https://github.com/google/sentencepiece#installation and follow the ones
# that match your environment. Please note that you may need to restart your runtime after installation.

# %%
train_tokenized = train_dataset.map(tokenize_function, remove_columns=features)
