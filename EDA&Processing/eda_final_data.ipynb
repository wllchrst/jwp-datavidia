# %%
import pandas as pd

# %%
df = pd.read_csv("../comodity-price-prediction-penyisihan-arkavidia-9/training_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date                        commodity province    price  \
# 0           0  2022-01-01  minyak goreng kemasan sederhana     Aceh  19400.0
# 1           1  2022-01-01             bawang putih bonggol     Aceh  27440.0
# 2           2  2022-01-01                     beras medium     Aceh  11030.0
# 3           3  2022-01-01                    gula konsumsi     Aceh  13520.0
# 4           4  2022-01-01                  daging ayam ras     Aceh  30540.0
#
#    GlobalOpen  GlobalHigh  GlobalLow  GlobalVol.  GlobalChange %  \
# 0    205.9048      782.25        3.5    228640.0           -0.48
# 1    205.9048      782.25        3.5    228640.0           -0.48
# 2    205.9048      782.25        3.5    228640.0           -0.48
# 3    205.9048      782.25        3.5    228640.0           -0.48
# 4    205.9048      782.25        3.5    228640.0           -0.48
#
#    GlobalGlobalCommodityAveragePrice  CE_Adj Close     CE_Close       CE_High  \
# ...
